# %% [markdown]
# # Parameter sweep from 2025-03-13

# %%
# Load parent data folder

parent_dir = '/Volumes/Microscopy/Wasatch-Raman_785/2025-03-13/attempt2/'

# Loop through all folders in the parent directory

import os
import numpy as np
import pandas as pd

folders = os.listdir(parent_dir)

# Parse metadata from each folder name

metadata = []

for folder in folders:
    if folder[0] != '.':
        metadata.append(folder.split('_'))

print(metadata)
# Out:
# [['attempt2', 'power=10', 'integration=1000', 'average=10'], ['attempt2', 'power=10', 'integration=1000', 'average=15'], ['attempt2', 'power=10', 'integration=1000', 'average=20'], ['attempt2', 'power=10', 'integration=1000', 'average=25'], ['attempt2', 'power=10', 'integration=1000', 'average=5'], ['attempt2', 'power=10', 'integration=1400', 'average=10'], ['attempt2', 'power=10', 'integration=1400', 'average=15'], ['attempt2', 'power=10', 'integration=1400', 'average=20'], ['attempt2', 'power=10', 'integration=1400', 'average=25'], ['attempt2', 'power=10', 'integration=1400', 'average=5'], ['attempt2', 'power=10', 'integration=1800', 'average=10'], ['attempt2', 'power=10', 'integration=1800', 'average=15'], ['attempt2', 'power=10', 'integration=1800', 'average=20'], ['attempt2', 'power=10', 'integration=1800', 'average=25'], ['attempt2', 'power=10', 'integration=1800', 'average=5'], ['attempt2', 'power=10', 'integration=200', 'average=10'], ['attempt2', 'power=10', 'integration=200
# ...
